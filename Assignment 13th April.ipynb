# %%
#Q1. What is Random Forest Regressor?

#Q2. How does Random Forest Regressor reduce the risk of overfitting?

#Q3. How does Random Forest Regressor aggregate the predictions of multiple decision trees?

# %% [markdown]
# Random Forest is an ensemble learning technique used for both classification and regression problems.
#
# It is a machine learning algorithm that can be used for a variety of tasks including regression and classification. Random Forest Regression is known to produce very robust results by avoiding overfitting.
#
# In this technique, multiple decision trees are created and their output is averaged to give the final result. Each decision tree is trained on a different subset of the data, and each tree makes its own prediction. The final prediction is then made by averaging the predictions of all the trees.

# %%
#Q4. What are the hyperparameters of Random Forest Regressor?

# %% [markdown]
# The most important hyper-parameters of a Random Forest that can be tuned are:
#
# n_estimators: It denotes the number of decision trees to be created in the random forest model. By default, it is 100.
#
# The criteria with which to split on each node (Gini or Entropy for a classification task, or the MSE or MAE for regression)
#
# The maximum depth of the individual trees.

# %%
#Q5. What is the difference between Random Forest Regressor and Decision Tree Regressor?

# %% [markdown]
# The main difference between Random Forest Regressor and Decision Tree Regressor is that Random Forest Regressor is an ensemble method that combines multiple decision trees to make predictions while Decision Tree Regressor uses only one decision tree
#
# Random Forest Regressor reduces the risk of overfitting and accuracy is much higher than a single decision tree

# %%
#Q6. What are the advantages and disadvantages of Random Forest Regressor?

# %% [markdown]
# Random Forest Regressor works well with both categorical and numerical data
# Random Forest Regressor reduces the risk of overfitting and accuracy is much higher than a single decision tree
#
# However, Random Forests can be computationally intensive for large datasets and are also not easily interpretable

# %%
#Q8. Can Random Forest Regressor be used for classification tasks?

# %% [markdown]
# Random Forest Regressor works well with both categorical and numerical data
