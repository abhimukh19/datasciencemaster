# %%
### Q1. What is Web Scraping? Why is it Used? Give three areas where Web Scraping is used to get data.

### A1. Web scraping (or data scraping) is a technique used to collect content and data from the internet. examples are below

### Market research: Web scraping can pull data from social media or online forums for things like customer sentiment analysis or competitor analysis.
### Price monitoring: Web scraping can track online prices of products or services across different websites and platforms for price regulation or comparison.
### Web indexing: Web scraping can crawl and index web pages for search engines or other purposes

# %%
### Q2. What are the different methods used for Web Scraping?

## A2 Web scraping methods can be divided into two categories: manual extraction techniques and automated extraction techniques
###  Manual extraction techniques involve copying and pasting the site content. Automated extraction techniques involve using web scraping tools that can crawl and index web pages using pre-programmed logic

# %%
### Q3 What is Beautiful Soup? Why is it used?
### A3 Beautiful Soup is a Python library for pulling data out of HTML and XML files. It helps make the parsed content more readable format and helps extract the right content as well

# %%
### Q4. Why is flask used in this Web Scraping project?
## A4 Flask is a lightweight framework to build websites. 
### It can be used in web scraping projects to parse the collected data and display it as HTML in a new HTML file for example review comments were added to the results.html file from flipkart website

# %%
### Q5 Write the names of AWS services used in this project. Also, explain the use of each service.
### A5 AWS ElasticBeanstalk - AWS Elastic Beanstalk is an orchestration service offered by Amazon Web Services for deploying application. It can automatically provision and manage various AWS resources, such as EC2, S3, SNS, CloudWatch, autoscaling, and Elastic Load Balancers
## AWS CodeCommit, AWS CodeDeploy, and AWS CodePipeline are AWS Developer Tools that can be used to create a CI/CD pipeline for an applications. 
## AWS CodeCommit is a fully managed source control service that hosts Git repositories
## AWS CodeDeploy is a fully managed deployment service that automates software deployments to various compute services such as EC2 (a cloud VM)
## AWS CodePipeline is a fully managed continuous delivery service that orchestrates release process based on defined models
