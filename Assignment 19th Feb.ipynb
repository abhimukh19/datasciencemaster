# %%
## Q1. What is Flask Framework? What are the advantages of Flask Framework?
## A1 Flask is a framework for web development using Python. It is not dependent on external libraries 

### Advantages of Flask Framework
## Easy to set up and use
## Supports dynamic web pages with templates
## Has a built-in development server and debugger
## Has a modular design that allows extensions

# %%
## Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![Flask2.png](attachment:d5b0d8b2-5eb8-4160-9f8c-fd6dddf87dbe.png)

# %% [markdown]
# ![helloworld flask.png](attachment:e377cf1d-3b9a-48f8-a814-eb15c9b4c890.png)

# %%
## Q3. What is App routing in Flask? Why do we use app routes?
## A3 App routing used to map a specific URL attached to a function/method that performs some task. It helps connects applications which may be built on different technology platforms to connect with each other via URLs

# %%
## Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details: Company Name: ABC Corporation Location: India Contact Detail: 999-999-9999

# %% [markdown]
# ![Flask3.png](attachment:4596d38e-c09c-4e2e-a762-51cdce580d39.png)

# %% [markdown]
# ![Flask4.png](attachment:6a1b3d0d-8993-433d-9703-ff66cfde6658.png)

# %% [markdown]
# ![Flask 5.png](attachment:a8f84c5d-853e-4cb5-b3fc-92a1bd8e1aeb.png)

# %%
## Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

## A5 This function creates a URL for a function on the runtime based on the name of the function and any keyword arguments corresponding to the variable parts of the URL rule

# %% [markdown]
# ![Flask7.png](attachment:2fbd0a9d-6f52-4db3-a78d-ec0a47b6e2c9.png)
