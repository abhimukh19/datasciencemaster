# %%
### Q1. Explain GET and POST methods.
### A1  GET and POST are HTTP methods that are used to send and receive data between a client and a server
### GET is used to request data from a web server, while POST is used to send data to a server

# %%
##Q2 Why is request used in Flask?
## A2 Request is used to access the data that is sent from the client to the server

# %%
## Q3 Why is redirect() used in Flask?
## A3 Redirect() sends a response object that redirects the user to another URL, for example after loggin in, you want to redirect the user to homepage page or the user's account page

# %%
## Q4 What are templates in Flask? Why is the render_template() function used?
## A4  The render_template() function is used to select a template file (example an entry form) from the templates folder and pass any values to another page( example publishing the result of a computational operation inside the python code to an html page)

# %%
### Q5 Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

### A5 Creating a simple subtract API to subtract two numbers

# %% [markdown]
# ![Post1.png](attachment:01e9fb52-3547-46af-9345-bdf3ffb028ac.png)

# %% [markdown]
# ![POST2.png](attachment:58feda47-d210-4ebf-a446-4af971d6becc.png)
